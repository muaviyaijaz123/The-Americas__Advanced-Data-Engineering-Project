# %%
import pandas as pd

# %%
pd.options.display.float_format = "{:.2f}".format
pd.set_option('display.max_columns', None)

wages_data = pd.read_csv("wages_by_education.csv")
employment_data = pd.read_csv("employment_to_population_1979_to_2022.csv")

# %%
wages_data.info()

# %%
employment_data.info()

# %%
wages_data.dtypes()

# %%
employment_data.dtypes()

# %%
wages_data.describe()

# %%
employment_data.describe()

# %% [markdown]
# # remove columns

# %%
wages_data_columns_to_keep = ['year'] + [col for col in wages_data.columns if 'white' in col or 'black' in col]
wages_data = wages_data[wages_data_columns_to_keep]

wages_years_to_remove = [1973,1974,1975,1976,1977,1978]
wages_data = wages_data[~wages_data["year"].isin(wages_years_to_remove)]

employment_data_to_keep = ['year'] + ['total_population'] + [col for col in employment_data.columns if 'white' in col or 'black' in col]
employment_data = employment_data[employment_data_to_keep]

# %%
wages_data.shape
# Out:
# (44, 31)

# %%
employment_data.shape
# Out:
# (44, 62)

# %% [markdown]
# # Renaming Columns

# %%
wages_data_mapper = {
    'white_less_than_hs': 'White_Less_HS_Hourly_Wage',
    'white_high_school': 'White_HS_Hourly_Wage',
    'white_some_college': 'White_Some_College_Hourly_Wage',
    'white_bachelors_degree': 'White_Bachelors_Hourly_Wage',
    'white_advanced_degree': 'White_Advanced_Hourly_Wage',
    'white_men_less_than_hs': 'White_Men_Less_HS_Hourly_Wage',
    'white_men_high_school': 'White_Men_HS_Hourly_Wage',
    'white_men_some_college': 'White_Men_Some_College_Hourly_Wage',
    'white_men_bachelors_degree': 'White_Men_Bachelors_Hourly_Wage',
    'white_men_advanced_degree': 'White_Men_Advanced_Hourly_Wage',
    'white_women_less_than_hs': 'White_Women_Less_HS_Hourly_Wage',
    'white_women_high_school': 'White_Women_HS_Hourly_Wage',
    'white_women_some_college': 'White_Women_Some_College_Hourly_Wage',
    'white_women_bachelors_degree': 'White_Women_Bachelors_Hourly_Wage',
    'white_women_advanced_degree': 'White_Women_Advanced_Hourly_Wage',
    'black_less_than_hs': 'Black_Less_HS_Hourly_Wage',
    'black_high_school': 'Black_HS_Hourly_Wage',
    'black_some_college': 'Black_Some_College_Hourly_Wage',
    'black_bachelors_degree': 'Black_Bachelors_Hourly_Wage',
    'black_advanced_degree': 'Black_Advanced_Hourly_Wage',
    'black_men_less_than_hs': 'Black_Men_Less_HS_Hourly_Wage',
    'black_men_high_school': 'Black_Men_HS_Hourly_Wage',
    'black_men_some_college': 'Black_Men_Some_College_Hourly_Wage',
    'black_men_bachelors_degree': 'Black_Men_Bachelors_Hourly_Wage',
    'black_men_advanced_degree': 'Black_Men_Advanced_Hourly_Wage',
    'black_women_less_than_hs': 'Black_Women_Less_HS_Hourly_Wage',
    'black_women_high_school': 'Black_Women_HS_Hourly_Wage',
    'black_women_some_college': 'Black_Women_Some_College_Hourly_Wage',
    'black_women_bachelors_degree': 'Black_Women_Bachelors_Degree_Hourly_Wage',
    'black_women_advanced_degree': 'Black_Women_Advanced_Degree_Hourly_Wage' 
}

employment_data_mapper = {
    'black': 'Black_Employment_Ratio_All_Ages',
    'black_16-24': 'Black_Employment_Ratio_Age_16_24',
    'black_25-54': 'Black_Employment_Ratio_Age_25_54',
    'black_55-64': 'Black_Employment_Ratio_Age_55_64',
    'black_65+': 'Black_Employment_Ratio_Age_65_Plus',
    'black_less_than_hs': 'Black_Employment_Ratio_Less_Than_High_School',
    'black_high_school': 'Black_Employment_Ratio_High_School',
    'black_some_college': 'Black_Employment_Ratio_Some_College',
    'black_bachelors_degree': 'Black_Employment_Ratio_Bachelors_Degree',
    'black_advanced_degree': 'Black_Employment_Ratio_Advanced_Degree',
    'black_women': 'Black_Women_Employment_Ratio_All_Ages',
    'black_women_16-24': 'Black_Women_Employment_Ratio_Age_16_24',
    'black_women_25-54': 'Black_Women_Employment_Ratio_Age_25_54',
    'black_women_55-64': 'Black_Women_Employment_Ratio_Age_55_64',
    'black_women_65+': 'Black_Women_Employment_Ratio_Age_65_Plus',
    'black_women_less_than_hs': 'Black_Women_Employment_Ratio_Less_Than_High_School',
    'black_women_high_school': 'Black_Women_Employment_Ratio_High_School',
    'black_women_some_college': 'Black_Women_Employment_Ratio_Some_College',
    'black_women_bachelors_degree': 'Black_Women_Employment_Ratio_Bachelors_Degree',
    'black_women_advanced_degree': 'Black_Women_Employment_Ratio_Advanced_Degree',
    'black_men': 'Black_Men_Employment_Ratio_All_Ages',
    'black_men_16-24': 'Black_Men_Employment_Ratio_Age_16_24',
    'black_men_25-54': 'Black_Men_Employment_Ratio_Age_25_54',
    'black_men_55-64': 'Black_Men_Employment_Ratio_Age_55_64',
    'black_men_65+': 'Black_Men_Employment_Ratio_Age_65_Plus',
    'black_men_less_than_hs': 'Black_Men_Employment_Ratio_Less_Than_High_School',
    'black_men_high_school': 'Black_Men_Employment_Ratio_High_School',
    'black_men_some_college': 'Black_Men_Employment_Ratio_Some_College',
    'black_men_bachelors_degree': 'Black_Men_Employment_Ratio_Bachelors_Degree',
    'black_men_advanced_degree': 'Black_Men_Employment_Ratio_Advanced_Degree',
    
    'white': 'White_Employment_Ratio_All_Ages',
    'white_16-24': 'White_Employment_Ratio_Age_16_24',
    'white_25-54': 'White_Employment_Ratio_Age_25_54',
    'white_55-64': 'White_Employment_Ratio_Age_55_64',
    'white_65+': 'White_Employment_Ratio_Age_65_Plus',
    'white_less_than_hs': 'White_Employment_Ratio_Less_Than_High_School',
    'white_high_school': 'White_Employment_Ratio_High_School',
    'white_some_college': 'White_Employment_Ratio_Some_College',
    'white_bachelors_degree': 'White_Employment_Ratio_Bachelors_Degree',
    'white_advanced_degree': 'White_Employment_Ratio_Advanced_Degree',
    'white_women': 'White_Women_Employment_Ratio_All_Ages',
    'white_women_16-24': 'White_Women_Employment_Ratio_Age_16_24',
    'white_women_25-54': 'White_Women_Employment_Ratio_Age_25_54',
    'white_women_55-64': 'White_Women_Employment_Ratio_Age_55_64',
    'white_women_65+': 'White_Women_Employment_Ratio_Age_65_Plus',
    'white_women_less_than_hs': 'White_Women_Employment_Ratio_Less_Than_High_School',
    'white_women_high_school': 'White_Women_Employment_Ratio_High_School',
    'white_women_some_college': 'White_Women_Employment_Ratio_Some_College',
    'white_women_bachelors_degree': 'White_Women_Employment_Ratio_Bachelors_Degree',
    'white_women_advanced_degree': 'White_Women_Employment_Ratio_Advanced_Degree',
    'white_men': 'White_Men_Employment_Ratio_All_Ages',
    'white_men_16-24': 'White_Men_Employment_Ratio_Age_16_24',
    'white_men_25-54': 'White_Men_Employment_Ratio_Age_25_54',
    'white_men_55-64': 'White_Men_Employment_Ratio_Age_55_64',
    'white_men_65+': 'White_Men_Employment_Ratio_Age_65_Plus',
    'white_men_less_than_hs': 'White_Men_Employment_Ratio_Less_Than_High_School',
    'white_men_high_school': 'White_Men_Employment_Ratio_High_School',
    'white_men_some_college': 'White_Men_Employment_Ratio_Some_College',
    'white_men_bachelors_degree': 'White_Men_Employment_Ratio_Bachelors_Degree',
    'white_men_advanced_degree': 'White_Men_Employment_Ratio_Advanced_Degree'
}
employment_data.rename(columns = employment_data_mapper, inplace = True)
wages_data.rename(columns = wages_data_mapper, inplace=True)

# %% [markdown]
# # Wages dataset column addition

# %%
white_columns = ['White_Less_HS_Hourly_Wage', 'White_HS_Hourly_Wage', 'White_Some_College_Hourly_Wage',
                 'White_Bachelors_Hourly_Wage', 'White_Advanced_Hourly_Wage']
wages_data['White_Average_Hourly_Wage'] = wages_data[white_columns].mean(axis=1)

black_columns = ['Black_Less_HS_Hourly_Wage', 'Black_HS_Hourly_Wage', 'Black_Some_College_Hourly_Wage',
                 'Black_Bachelors_Hourly_Wage', 'Black_Advanced_Hourly_Wage']
wages_data['Black_Average_Hourly_Wage'] = wages_data[black_columns].mean(axis=1)
wages_data.head(5)
# Out:
#    year  White_Less_HS_Hourly_Wage  White_HS_Hourly_Wage  \
# 0  2022                      15.70                 23.31
# 1  2021                      16.20                 23.60
# 2  2020                      17.01                 24.00
# 3  2019                      15.89                 22.94
# 4  2018                      16.05                 23.02
#
#    White_Some_College_Hourly_Wage  White_Bachelors_Hourly_Wage  \
# 0                           26.28                        43.30
# 1                           26.29                        43.06
# 2                           26.90                        43.16
# 3                           25.47                        41.06
# 4                           25.15                        40.49
#
#    White_Advanced_Hourly_Wage  Black_Less_HS_Hourly_Wage  \
# 0                       53.30                      15.19
# 1                       53.62                      14.55
# 2                       53.80                      14.55
# 3                       51.81                      14.19
# 4                       51.80                      13.31
#
#    Black_HS_Hourly_Wage  Black_Some_College_Hourly_Wage  \
# 0                 19.39                           21.34
# 1                 19.66                           21.26
# 2                 19.66                           21.79
# 3                 18.73                           20.44
# 4                 18.14                           19.98
#
#    Black_Bachelors_Hourly_Wage  Black_Advanced_Hourly_Wage  \
# 0                        33.39                       44.67
# 1                        32.62                       43.37
# 2                        33.64                       45.76
# 3                        31.83                       42.73
# 4                        32.00                       42.22
#
#    White_Men_Less_HS_Hourly_Wage  White_Men_HS_Hourly_Wage  \
# 0                          17.14                     25.92
# 1                          18.13                     26.03
# 2                          18.97                     26.73
# 3                          17.66                     25.58
# 4                          17.96                     25.49
#
#    White_Men_Some_College_Hourly_Wage  White_Men_Bachelors_Hourly_Wage  \
# 0                               29.93                            51.23
# 1                               29.79                            50.06
# 2                               30.40                            50.15
# 3                               28.90                            47.76
# 4                               28.41                            47.28
#
#    White_Men_Advanced_Hourly_Wage  Black_Men_Less_HS_Hourly_Wage  \
# 0                           63.86                          16.38
# 1                           64.04                          15.38
# 2                           63.50                          15.52
# 3                           60.84                          15.07
# 4                           61.27                          14.27
#
#    Black_Men_HS_Hourly_Wage  Black_Men_Some_College_Hourly_Wage  \
# 0                     20.73                               22.58
# 1                     20.86                               22.63
# 2                     21.22                               23.57
# 3                     20.22                               22.02
# 4                     19.36                               21.82
#
#    Black_Men_Bachelors_Hourly_Wage  Black_Men_Advanced_Hourly_Wage  \
# 0                            37.63                           52.91
# 1                            36.95                           49.01
# 2                            36.70                           51.67
# 3                            33.73                           46.87
# 4                            33.42                           46.42
#
#    White_Women_Less_HS_Hourly_Wage  White_Women_HS_Hourly_Wage  \
# 0                            13.84                       19.56
# 1                            13.77                       20.08
# 2                            14.20                       20.06
# 3                            13.44                       19.22
# 4                            13.45                       19.52
#
#    White_Women_Some_College_Hourly_Wage  White_Women_Bachelors_Hourly_Wage  \
# 0                                 22.52                              35.31
# 1                                 22.73                              36.11
# 2                                 23.31                              36.20
# 3                                 21.99                              34.47
# 4                                 21.90                              33.78
#
#    White_Women_Advanced_Hourly_Wage  Black_Women_Less_HS_Hourly_Wage  \
# 0                             44.45                            13.89
# 1                             44.82                            13.73
# 2                             45.58                            13.66
# 3                             43.83                            13.30
# 4                             43.31                            12.48
#
#    Black_Women_HS_Hourly_Wage  Black_Women_Some_College_Hourly_Wage  \
# 0                       17.83                                 20.36
# 1                       18.30                                 20.18
# 2                       17.93                                 20.31
# 3                       17.18                                 19.17
# 4                       16.81                                 18.57
#
#    Black_Women_Bachelors_Degree_Hourly_Wage  \
# 0                                     29.94
# 1                                     29.35
# 2                                     31.38
# 3                                     30.31
# 4                                     30.85
#
#    Black_Women_Advanced_Degree_Hourly_Wage  White_Average_Hourly_Wage  \
# 0                                    39.41                      32.38
# 1                                    40.07                      32.55
# 2                                    42.44                      32.97
# 3                                    40.42                      31.43
# 4                                    39.64                      31.30
#
#    Black_Average_Hourly_Wage
# 0                      26.80
# 1                      26.29
# 2                      27.08
# 3                      25.58
# 4                      25.13

# %% [markdown]
# # Merging datasets

# %%
#wages_data = wages_data[wages_data['year'] != 2022]
merged_data_set = pd.merge(wages_data,employment_data)

# %% [markdown]
# # Set 'year' column to key_index

# %%
#merged_data_set.set_index("year", inplace = True)
merged_data_set["total_population"]
cols = list(merged_data_set.columns)
cols.remove("total_population")  # Remove the column you want to move
cols.insert(1, "total_population")  # Insert the column at the new position

# Reorder the DataFrame
merged_data_set = merged_data_set[cols]

# %%
 merged_data_set.head(5)
# Out:
#    year  total_population  White_Less_HS_Hourly_Wage  White_HS_Hourly_Wage  \
# 0  2022         333287557                      15.70                 23.31
# 1  2021         332031554                      16.20                 23.60
# 2  2020         331511512                      17.01                 24.00
# 3  2019         328329953                      15.89                 22.94
# 4  2018         326838199                      16.05                 23.02
#
#    White_Some_College_Hourly_Wage  White_Bachelors_Hourly_Wage  \
# 0                           26.28                        43.30
# 1                           26.29                        43.06
# 2                           26.90                        43.16
# 3                           25.47                        41.06
# 4                           25.15                        40.49
#
#    White_Advanced_Hourly_Wage  Black_Less_HS_Hourly_Wage  \
# 0                       53.30                      15.19
# 1                       53.62                      14.55
# 2                       53.80                      14.55
# 3                       51.81                      14.19
# 4                       51.80                      13.31
#
#    Black_HS_Hourly_Wage  Black_Some_College_Hourly_Wage  \
# 0                 19.39                           21.34
# 1                 19.66                           21.26
# 2                 19.66                           21.79
# 3                 18.73                           20.44
# 4                 18.14                           19.98
#
#    Black_Bachelors_Hourly_Wage  Black_Advanced_Hourly_Wage  \
# 0                        33.39                       44.67
# 1                        32.62                       43.37
# 2                        33.64                       45.76
# 3                        31.83                       42.73
# 4                        32.00                       42.22
#
#    White_Men_Less_HS_Hourly_Wage  White_Men_HS_Hourly_Wage  \
# 0                          17.14                     25.92
# 1                          18.13                     26.03
# 2                          18.97                     26.73
# 3                          17.66                     25.58
# 4                          17.96                     25.49
#
#    White_Men_Some_College_Hourly_Wage  White_Men_Bachelors_Hourly_Wage  \
# 0                               29.93                            51.23
# 1                               29.79                            50.06
# 2                               30.40                            50.15
# 3                               28.90                            47.76
# 4                               28.41                            47.28
#
#    White_Men_Advanced_Hourly_Wage  Black_Men_Less_HS_Hourly_Wage  \
# 0                           63.86                          16.38
# 1                           64.04                          15.38
# 2                           63.50                          15.52
# 3                           60.84                          15.07
# 4                           61.27                          14.27
#
#    Black_Men_HS_Hourly_Wage  Black_Men_Some_College_Hourly_Wage  \
# 0                     20.73                               22.58
# 1                     20.86                               22.63
# 2                     21.22                               23.57
# 3                     20.22                               22.02
# 4                     19.36                               21.82
#
#    Black_Men_Bachelors_Hourly_Wage  Black_Men_Advanced_Hourly_Wage  \
# 0                            37.63                           52.91
# 1                            36.95                           49.01
# 2                            36.70                           51.67
# 3                            33.73                           46.87
# 4                            33.42                           46.42
#
#    White_Women_Less_HS_Hourly_Wage  White_Women_HS_Hourly_Wage  \
# 0                            13.84                       19.56
# 1                            13.77                       20.08
# 2                            14.20                       20.06
# 3                            13.44                       19.22
# 4                            13.45                       19.52
#
#    White_Women_Some_College_Hourly_Wage  White_Women_Bachelors_Hourly_Wage  \
# 0                                 22.52                              35.31
# 1                                 22.73                              36.11
# 2                                 23.31                              36.20
# 3                                 21.99                              34.47
# 4                                 21.90                              33.78
#
#    White_Women_Advanced_Hourly_Wage  Black_Women_Less_HS_Hourly_Wage  \
# 0                             44.45                            13.89
# 1                             44.82                            13.73
# 2                             45.58                            13.66
# 3                             43.83                            13.30
# 4                             43.31                            12.48
#
#    Black_Women_HS_Hourly_Wage  Black_Women_Some_College_Hourly_Wage  \
# 0                       17.83                                 20.36
# 1                       18.30                                 20.18
# 2                       17.93                                 20.31
# 3                       17.18                                 19.17
# 4                       16.81                                 18.57
#
#    Black_Women_Bachelors_Degree_Hourly_Wage  \
# 0                                     29.94
# 1                                     29.35
# 2                                     31.38
# 3                                     30.31
# 4                                     30.85
#
#    Black_Women_Advanced_Degree_Hourly_Wage  White_Average_Hourly_Wage  \
# 0                                    39.41                      32.38
# 1                                    40.07                      32.55
# 2                                    42.44                      32.97
# 3                                    40.42                      31.43
# 4                                    39.64                      31.30
#
#    Black_Average_Hourly_Wage  Black_Employment_Ratio_All_Ages  \
# 0                      26.80                            56.00
# 1                      26.29                            53.30
# 2                      27.08                            58.90
# 3                      25.58                            58.40
# 4                      25.13                            57.60
#
#    Black_Employment_Ratio_Age_16_24  Black_Employment_Ratio_Age_25_54  \
# 0                             43.40                             72.90
# 1                             39.40                             69.80
# 2                             46.10                             76.40
# 3                             45.40                             75.90
# 4                             45.00                             74.60
#
#    Black_Employment_Ratio_Age_55_64  Black_Employment_Ratio_Age_65_Plus  \
# 0                             53.90                               17.60
# 1                             51.80                               16.00
# 2                             55.30                               17.70
# 3                             54.50                               16.90
# 4                             52.60                               17.10
#
#    Black_Employment_Ratio_Less_Than_High_School  \
# 0                                         23.60
# 1                                         23.80
# 2                                         26.60
# 3                                         26.40
# 4                                         25.90
#
#    Black_Employment_Ratio_High_School  Black_Employment_Ratio_Some_College  \
# 0                               52.10                                60.40
# 1                               48.00                                57.30
# 2                               55.20                                65.00
# 3                               55.60                                64.10
# 4                               54.90                                64.20
#
#    Black_Employment_Ratio_Bachelors_Degree  \
# 0                                    72.30
# 1                                    70.40
# 2                                    75.20
# 3                                    75.40
# 4                                    74.60
#
#    Black_Employment_Ratio_Advanced_Degree  \
# 0                                   75.10
# 1                                   73.80
# 2                                   76.10
# 3                                   76.30
# 4                                   76.30
#
#    Black_Women_Employment_Ratio_All_Ages  \
# 0                                  54.60
# 1                                  52.20
# 2                                  57.50
# 3                                  56.90
# 4                                  56.10
#
#    Black_Women_Employment_Ratio_Age_16_24  \
# 0                                   44.20
# 1                                   40.50
# 2                                   48.10
# 3                                   47.50
# 4                                   47.40
#
#    Black_Women_Employment_Ratio_Age_25_54  \
# 0                                   72.20
# 1                                   68.80
# 2                                   74.80
# 3                                   74.10
# 4                                   72.90
#
#    Black_Women_Employment_Ratio_Age_55_64  \
# 0                                   52.40
# 1                                   51.70
# 2                                   54.70
# 3                                   53.10
# 4                                   50.90
#
#    Black_Women_Employment_Ratio_Age_65_Plus  \
# 0                                     15.90
# 1                                     14.60
# 2                                     16.50
# 3                                     15.90
# 4                                     15.50
#
#    Black_Women_Employment_Ratio_Less_Than_High_School  \
# 0                                              22.70
# 1                                              23.90
# 2                                              25.90
# 3                                              26.20
# 4                                              25.70
#
#    Black_Women_Employment_Ratio_High_School  \
# 0                                     48.10
# 1                                     44.40
# 2                                     51.70
# 3                                     51.80
# 4                                     51.20
#
#    Black_Women_Employment_Ratio_Some_College  \
# 0                                      58.50
# 1                                      55.20
# 2                                      63.10
# 3                                      62.40
# 4                                      62.60
#
#    Black_Women_Employment_Ratio_Bachelors_Degree  \
# 0                                          70.10
# 1                                          68.10
# 2                                          72.70
# 3                                          73.20
# 4                                          72.50
#
#    Black_Women_Employment_Ratio_Advanced_Degree  \
# 0                                         74.30
# 1                                         73.40
# 2                                         75.70
# 3                                         76.40
# 4                                         75.50
#
#    Black_Men_Employment_Ratio_All_Ages  Black_Men_Employment_Ratio_Age_16_24  \
# 0                                57.50                                 42.50
# 1                                54.60                                 38.20
# 2                                60.50                                 43.90
# 3                                60.20                                 43.10
# 4                                59.30                                 42.50
#
#    Black_Men_Employment_Ratio_Age_25_54  Black_Men_Employment_Ratio_Age_55_64  \
# 0                                 73.60                                 55.60
# 1                                 71.00                                 51.90
# 2                                 78.20                                 56.10
# 3                                 78.00                                 56.10
# 4                                 76.50                                 54.60
#
#    Black_Men_Employment_Ratio_Age_65_Plus  \
# 0                                   20.10
# 1                                   18.00
# 2                                   19.60
# 3                                   18.40
# 4                                   19.40
#
#    Black_Men_Employment_Ratio_Less_Than_High_School  \
# 0                                             24.40
# 1                                             23.60
# 2                                             27.30
# 3                                             26.60
# 4                                             26.00
#
#    Black_Men_Employment_Ratio_High_School  \
# 0                                   55.90
# 1                                   51.50
# 2                                   58.60
# 3                                   59.50
# 4                                   58.70
#
#    Black_Men_Employment_Ratio_Some_College  \
# 0                                    62.90
# 1                                    60.00
# 2                                    67.40
# 3                                    66.20
# 4                                    66.20
#
#    Black_Men_Employment_Ratio_Bachelors_Degree  \
# 0                                        75.20
# 1                                        73.40
# 2                                        78.40
# 3                                        78.30
# 4                                        77.30
#
#    Black_Men_Employment_Ratio_Advanced_Degree  \
# 0                                       76.30
# 1                                       74.50
# 2                                       76.80
# 3                                       76.10
# 4                                       77.40
#
#    White_Employment_Ratio_All_Ages  White_Employment_Ratio_Age_16_24  \
# 0                            58.10                             54.60
# 1                            56.70                             49.80
# 2                            60.30                             55.20
# 3                            60.10                             54.40
# 4                            59.90                             54.20
#
#    White_Employment_Ratio_Age_25_54  White_Employment_Ratio_Age_55_64  \
# 0                             80.40                             63.70
# 1                             78.50                             62.00
# 2                             82.20                             65.20
# 3                             81.50                             65.00
# 4                             80.90                             64.50
#
#    White_Employment_Ratio_Age_65_Plus  \
# 0                               18.20
# 1                               18.10
# 2                               19.90
# 3                               19.30
# 4                               18.90
#
#    White_Employment_Ratio_Less_Than_High_School  \
# 0                                         32.20
# 1                                         29.20
# 2                                         32.20
# 3                                         31.70
# 4                                         31.00
#
#    White_Employment_Ratio_High_School  White_Employment_Ratio_Some_College  \
# 0                               50.70                                58.10
# 1                               49.60                                56.10
# 2                               53.90                                60.60
# 3                               53.40                                61.10
# 4                               53.30                                61.30
#
#    White_Employment_Ratio_Bachelors_Degree  \
# 0                                    68.90
# 1                                    67.50
# 2                                    71.30
# 3                                    71.50
# 4                                    71.60
#
#    White_Employment_Ratio_Advanced_Degree  \
# 0                                   68.70
# 1                                   68.40
# 2                                   71.50
# 3                                   71.40
# 4                                   71.60
#
#    White_Women_Employment_Ratio_All_Ages  \
# 0                                  53.30
# 1                                  51.60
# 2                                  55.00
# 3                                  54.70
# 4                                  54.60
#
#    White_Women_Employment_Ratio_Age_16_24  \
# 0                                   55.10
# 1                                   49.40
# 2                                   55.30
# 3                                   54.50
# 4                                   54.10
#
#    White_Women_Employment_Ratio_Age_25_54  \
# 0                                   75.30
# 1                                   73.20
# 2                                   76.60
# 3                                   75.50
# 4                                   75.00
#
#    White_Women_Employment_Ratio_Age_55_64  \
# 0                                   58.70
# 1                                   56.40
# 2                                   59.50
# 3                                   59.60
# 4                                   59.20
#
#    White_Women_Employment_Ratio_Age_65_Plus  \
# 0                                     14.60
# 1                                     14.40
# 2                                     16.00
# 3                                     15.50
# 4                                     15.10
#
#    White_Women_Employment_Ratio_Less_Than_High_School  \
# 0                                              28.50
# 1                                              24.00
# 2                                              26.90
# 3                                              27.00
# 4                                              26.10
#
#    White_Women_Employment_Ratio_High_School  \
# 0                                     41.20
# 1                                     39.90
# 2                                     44.30
# 3                                     43.50
# 4                                     43.50
#
#    White_Women_Employment_Ratio_Some_College  \
# 0                                      53.40
# 1                                      51.30
# 2                                      55.20
# 3                                      56.00
# 4                                      56.50
#
#    White_Women_Employment_Ratio_Bachelors_Degree  \
# 0                                          64.70
# 1                                          63.10
# 2                                          67.20
# 3                                          67.30
# 4                                          67.30
#
#    White_Women_Employment_Ratio_Advanced_Degree  \
# 0                                         68.00
# 1                                         67.30
# 2                                         70.50
# 3                                         70.00
# 4                                         70.30
#
#    White_Men_Employment_Ratio_All_Ages  White_Men_Employment_Ratio_Age_16_24  \
# 0                                63.20                                 54.20
# 1                                62.00                                 50.10
# 2                                65.90                                 55.00
# 3                                65.70                                 54.20
# 4                                65.50                                 54.40
#
#    White_Men_Employment_Ratio_Age_25_54  White_Men_Employment_Ratio_Age_55_64  \
# 0                                 85.50                                 68.90
# 1                                 83.90                                 67.90
# 2                                 87.80                                 71.30
# 3                                 87.60                                 70.60
# 4                                 86.80                                 70.10
#
#    White_Men_Employment_Ratio_Age_65_Plus  \
# 0                                   22.40
# 1                                   22.50
# 2                                   24.50
# 3                                   23.80
# 4                                   23.40
#
#    White_Men_Employment_Ratio_Less_Than_High_School  \
# 0                                             35.50
# 1                                             33.80
# 2                                             36.90
# 3                                             35.90
# 4                                             35.70
#
#    White_Men_Employment_Ratio_High_School  \
# 0                                   59.70
# 1                                   58.80
# 2                                   63.30
# 3                                   63.10
# 4                                   62.90
#
#    White_Men_Employment_Ratio_Some_College  \
# 0                                    63.50
# 1                                    61.60
# 2                                    66.80
# 3                                    66.90
# 4                                    66.90
#
#    White_Men_Employment_Ratio_Bachelors_Degree  \
# 0                                        73.50
# 1                                        72.50
# 2                                        75.80
# 3                                        76.10
# 4                                        76.20
#
#    White_Men_Employment_Ratio_Advanced_Degree
# 0                                       69.60
# 1                                       69.70
# 2                                       72.70
# 3                                       72.90
# 4                                       73.00

# %%
merged_data_set.dtypes
# Out:
# year                                                  int64
# total_population                                      int64
# White_Less_HS_Hourly_Wage                           float64
# White_HS_Hourly_Wage                                float64
# White_Some_College_Hourly_Wage                      float64
#                                                      ...
# White_Men_Employment_Ratio_Less_Than_High_School    float64
# White_Men_Employment_Ratio_High_School              float64
# White_Men_Employment_Ratio_Some_College             float64
# White_Men_Employment_Ratio_Bachelors_Degree         float64
# White_Men_Employment_Ratio_Advanced_Degree          float64
# Length: 92, dtype: object

# %% [markdown]
# # Changing data types

# %%
merged_data_set["year"] = merged_data_set["year"].astype("int16")
merged_data_set = merged_data_set.astype({col: "float32" for col in merged_data_set.columns if col != "year" and col != "total_population"})

# %%
white_columns = ['White_Less_HS_Hourly_Wage', 'White_HS_Hourly_Wage', 'White_Some_College_Hourly_Wage',
                 'White_Bachelors_Hourly_Wage', 'White_Advanced_Hourly_Wage']
merged_data_set['White_Average_Hourly_Wage'] = merged_data_set[white_columns].mean(axis=1)

black_columns = ['Black_Less_HS_Hourly_Wage', 'Black_HS_Hourly_Wage', 'Black_Some_College_Hourly_Wage',
                 'Black_Bachelors_Hourly_Wage', 'Black_Advanced_Hourly_Wage']
merged_data_set['Black_Average_Hourly_Wage'] = merged_data_set[black_columns].mean(axis=1)

# %% [markdown]
# # remove duplicate rows

# %%
def drop_duplicates(df, columns_subset = None):
    return df.drop_duplicates(subset = columns_subset)

# %% [markdown]
# # fill missing na values with appropriate strategy (mode, median, mode)

# %%
def fill_missing_values(df, columns, strategy = "mean"):
    
    for col in columns:
        if col in df.columns:
            value_to_fill = 0
            if(strategy == "mean"):
                value_to_fill = df[col].mean()
            elif(strategy == "mode"):
                value_to_fill = df[col].mode()[0]
            elif(strategy == "median"):
                value_to_fill = df[col].median()
            else:
                print("Unknown strategy paramter passed")
                return df

            df[col].fillna(value_to_fill, inplace=True)
    return df



def fill_missing_values_excluding_columns(df, exclude_columns = [], strategy = "mean"):

    columns_to_fill = [col for col in df.columns if col not in exclude_column]
    
    
    for col in columns_to_fill:
        if col in df.columns:
            value_to_fill = 0
            if(strategy == "mean"):
                value_to_fill = df[col].mean()
            elif(strategy == "mode"):
                value_to_fill = df[col].mode()[0]
            elif(strategy == "median"):
                value_to_fill = df[col].median()
            else:
                print("Unknown strategy paramter passed")
                return df

            df[col].fillna(value_to_fill, inplace=True)
    
    return df

# Example usage
# Assuming 'wages_data' is your DataFrame and you want to exclude the 'year' column
wages_data = fill_missing_with_mean_excluding(wages_data, 'year')

# Display the updated DataFrame
print(wages_data.head())

# %%
for column in employment_data.columns:
    print(f"{column}: {employment_data[column].dtype}")
# Out:
# year: int64
# all: float64
# 16-24: float64
# 25-54: float64
# 55-64: float64
# 65+: float64
# less_than_hs: float64
# high_school: float64
# some_college: float64
# bachelors_degree: float64
# advanced_degree: float64
# women: float64
# women_16-24: float64
# women_25-54: float64
# women_55-64: float64
# women_65+: float64
# women_less_than_hs: float64
# women_high_school: float64
# women_some_college: float64
# women_bachelors_degree: float64
# women_advanced_degree: float64
# men: float64
# men_16-24: float64
# men_25-54: float64
# men_55-64: float64
# men_65+: float64
# men_less_than_hs: float64
# men_high_school: float64
# men_some_college: float64
# men_bachelors_degree: float64
# men_advanced_degree: float64
# black: float64
# black_16-24: float64
# black_25-54: float64
# black_55-64: float64
# black_65+: float64
# black_less_than_hs: float64
# black_high_school: float64
# black_some_college: float64
# black_bachelors_degree: float64
# black_advanced_degree: float64
# black_women: float64
# black_women_16-24: float64
# black_women_25-54: float64
# black_women_55-64: float64
# black_women_65+: float64
# black_women_less_than_hs: float64
# black_women_high_school: float64
# black_women_some_college: float64
# black_women_bachelors_degree: float64
# black_women_advanced_degree: float64
# black_men: float64
# black_men_16-24: float64
# black_men_25-54: float64
# black_men_55-64: float64
# black_men_65+: float64
# black_men_less_than_hs: float64
# black_men_high_school: float64
# black_men_some_college: float64
# black_men_bachelors_degree: float64
# black_men_advanced_degree: float64
# hispanic: float64
# hispanic_16-24: float64
# hispanic_25-54: float64
# hispanic_55-64: float64
# hispanic_65+: float64
# hispanic_less_than_hs: float64
# hispanic_high_school: float64
# hispanic_some_college: float64
# hispanic_bachelors_degree: float64
# hispanic_advanced_degree: float64
# hispanic_women: float64
# hispanic_women_16-24: float64
# hispanic_women_25-54: float64
# hispanic_women_55-64: float64
# hispanic_women_65+: float64
# hispanic_women_less_than_hs: float64
# hispanic_women_high_school: float64
# hispanic_women_some_college: float64
# hispanic_women_bachelors_degree: float64
# hispanic_women_advanced_degree: float64
# hispanic_men: float64
# hispanic_men_16-24: float64
# hispanic_men_25-54: float64
# hispanic_men_55-64: float64
# hispanic_men_65+: float64
# hispanic_men_less_than_hs: float64
# hispanic_men_high_school: float64
# hispanic_men_some_college: float64
# hispanic_men_bachelors_degree: float64
# hispanic_men_advanced_degree: float64
# white: float64
# white_16-24: float64
# white_25-54: float64
# white_55-64: float64
# white_65+: float64
# white_less_than_hs: float64
# white_high_school: float64
# white_some_college: float64
# white_bachelors_degree: float64
# white_advanced_degree: float64
# white_women: float64
# white_women_16-24: float64
# white_women_25-54: float64
# white_women_55-64: float64
# white_women_65+: float64
# white_women_less_than_hs: float64
# white_women_high_school: float64
# white_women_some_college: float64
# white_women_bachelors_degree: float64
# white_women_advanced_degree: float64
# white_men: float64
# white_men_16-24: float64
# white_men_25-54: float64
# white_men_55-64: float64
# white_men_65+: float64
# white_men_less_than_hs: float64
# white_men_high_school: float64
# white_men_some_college: float64
# white_men_bachelors_degree: float64
# white_men_advanced_degree: float64
# total_population: int64

# %% [markdown]
# # Fill missing column values with mean except YEAR column

# %%
wages_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 31 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   year                          50 non-null     int64
#  1   white_less_than_hs            50 non-null     float64
#  2   white_high_school             50 non-null     float64
#  3   white_some_college            50 non-null     float64
#  4   white_bachelors_degree        50 non-null     float64
#  5   white_advanced_degree         50 non-null     float64
#  6   black_less_than_hs            50 non-null     float64
#  7   black_high_school             50 non-null     float64
#  8   black_some_college            50 non-null     float64
#  9   black_bachelors_degree        50 non-null     float64
#  10  black_advanced_degree         50 non-null     float64
#  11  white_men_less_than_hs        50 non-null     float64
#  12  white_men_high_school         50 non-null     float64
#  13  white_men_some_college        50 non-null     float64
#  14  white_men_bachelors_degree    50 non-null     float64
#  15  white_men_advanced_degree     50 non-null     float64
#  16  black_men_less_than_hs        50 non-null     float64
#  17  black_men_high_school         50 non-null     float64
#  18  black_men_some_college        50 non-null     float64
#  19  black_men_bachelors_degree    50 non-null     float64
#  20  black_men_advanced_degree     50 non-null     float64
#  21  white_women_less_than_hs      50 non-null     float64
#  22  white_women_high_school       50 non-null     float64
#  23  white_women_some_college      50 non-null     float64
#  24  white_women_bachelors_degree  50 non-null     float64
#  25  white_women_advanced_degree   50 non-null     float64
#  26  black_women_less_than_hs      50 non-null     float64
#  27  black_women_high_school       50 non-null     float64
#  28  black_women_some_college      50 non-null     float64
#  29  black_women_bachelors_degree  50 non-null     float64
#  30  black_women_advanced_degree   50 non-null     float64
# dtypes: float64(30), int64(1)
# memory usage: 12.2 KB

# %%
employment_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   year                          44 non-null     int64
#  1   black                         44 non-null     float64
#  2   black_16-24                   44 non-null     float64
#  3   black_25-54                   44 non-null     float64
#  4   black_55-64                   44 non-null     float64
#  5   black_65+                     44 non-null     float64
#  6   black_less_than_hs            44 non-null     float64
#  7   black_high_school             44 non-null     float64
#  8   black_some_college            44 non-null     float64
#  9   black_bachelors_degree        44 non-null     float64
#  10  black_advanced_degree         44 non-null     float64
#  11  black_women                   44 non-null     float64
#  12  black_women_16-24             44 non-null     float64
#  13  black_women_25-54             44 non-null     float64
#  14  black_women_55-64             44 non-null     float64
#  15  black_women_65+               44 non-null     float64
#  16  black_women_less_than_hs      44 non-null     float64
#  17  black_women_high_school       44 non-null     float64
#  18  black_women_some_college      44 non-null     float64
#  19  black_women_bachelors_degree  44 non-null     float64
#  20  black_women_advanced_degree   44 non-null     float64
#  21  black_men                     44 non-null     float64
#  22  black_men_16-24               44 non-null     float64
#  23  black_men_25-54               44 non-null     float64
#  24  black_men_55-64               44 non-null     float64
#  25  black_men_65+                 44 non-null     float64
#  26  black_men_less_than_hs        44 non-null     float64
#  27  black_men_high_school         44 non-null     float64
#  28  black_men_some_college        44 non-null     float64
#  29  black_men_bachelors_degree    44 non-null     float64
#  30  black_men_advanced_degree     44 non-null     float64
#  31  white                         44 non-null     float64
#  32  white_16-24                   44 non-null     float64
#  33  white_25-54                   44 non-null     float64
#  34  white_55-64                   44 non-null     float64
#  35  white_65+                     44 non-null     float64
#  36  white_less_than_hs            44 non-null     float64
#  37  white_high_school             44 non-null     float64
#  38  white_some_college            44 non-null     float64
#  39  white_bachelors_degree        44 non-null     float64
#  40  white_advanced_degree         44 non-null     float64
#  41  white_women                   44 non-null     float64
#  42  white_women_16-24             44 non-null     float64
#  43  white_women_25-54             44 non-null     float64
#  44  white_women_55-64             44 non-null     float64
#  45  white_women_65+               44 non-null     float64
#  46  white_women_less_than_hs      44 non-null     float64
#  47  white_women_high_school       44 non-null     float64
#  48  white_women_some_college      44 non-null     float64
#  49  white_women_bachelors_degree  44 non-null     float64
#  50  white_women_advanced_degree   44 non-null     float64
#  51  white_men                     44 non-null     float64
#  52  white_men_16-24               44 non-null     float64
#  53  white_men_25-54               44 non-null     float64
#  54  white_men_55-64               44 non-null     float64
#  55  white_men_65+                 44 non-null     float64
#  56  white_men_less_than_hs        44 non-null     float64
#  57  white_men_high_school         44 non-null     float64
#  58  white_men_some_college        44 non-null     float64
#  59  white_men_bachelors_degree    44 non-null     float64
#  60  white_men_advanced_degree     44 non-null     float64
# dtypes: float64(60), int64(1)
# memory usage: 21.1 KB
